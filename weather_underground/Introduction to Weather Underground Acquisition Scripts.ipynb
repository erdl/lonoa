# %% [markdown]
# # Weather Underground API Script

# %% [markdown]
# The purpose of this notebook is to illustrate 2 scripts to acquire data from Weather Undergroud.
#
# The first script download data as-is in JSON format, provided a `start date`, `end date` and a `station id`. The second parses the data out of the JSON files and store in a format acceptable by our current database schema.

# %% [markdown]
# ## API Request Script

# %% [markdown]
# In order to use the API, we need to register for a key. The key does NOT give unlimited access. About 1 year worth of data can be requested per day. If you exceed the amount of requests, it will timeout until the following day. Exception to this is their `raindrop` system. Check API Documentation for more details. On the script version of this notebook, the key is passed as a parameter to run the script rather than loaded from the file.

# %%
with open('keys/api.txt', 'r') as f:
    key = f.readline().rstrip()

# %% [markdown]
# Next, we specify:
#
#  * `start date` (inclusive): YYYYMMDD
#  * `end date` (inclusive): YYYYMMDD
#  * `station ID`: Check on Weather Underground website (e.g. https://www.wunderground.com/cgi-bin/findweather/getForecast?query=pws:KHIKAPOL23) the ID is **KHIKAPOL23**.
#  * `save_path`: Path to the folder where the downloaded readings will be stored (one file per day worth of readings, each containing as name the timestamp of the given day).

# %%
#Will be loaded as parameter when running the script
start_date = '20160101'
end_date = '20170101'
station_id = 'KHIKAPOL23'
save_path = "data/"

# %% [markdown]
# The script then uses the API key, start date, end date, station id and save path to:
#
#  * Enumerate all the list of dates in the range, inclusive (create_list_of_dates)
#  * Use one date at a time to create the URL for request worth one day of readings (this is WU's API interface constraint) (create_request_url).
#  * Store the date in an individual JSON file as-is so we can preserve the raw data if we ever need again to extract any additional information years later that was not stored at this point in time in the database by the second script. (download_one_day_readings).

# %%
import datetime
def create_list_of_dates(start_date,end_date):
    '''Creates a list of dates based on start and end date, inclusive for both dates. Requestes uses one date at a time.'''
    #start = datetime.datetime.strptime("21-06-2014", "%d-%m-%Y")
    start = datetime.datetime.strptime(start_date, "%Y%m%d")
    end = datetime.datetime.strptime(end_date, "%Y%m%d")
    dates_list = [start + datetime.timedelta(days=x) for x in range(0, (end-start).days+1)]
    return dates_list

def create_request_url(date,station_id,key):
    '''Creates the URL to obtain the data. This is just a formatting function, it does not send the request itself.'''
    api_url = 'http://api.wunderground.com/api/'
    key = key+'/'
    date = 'history_' + date + '/'
    station = 'q/pws:'+station_id+'.json'
    return (api_url+key+date+station)

import urllib.request
import shutil
def download_one_day_readings(date,url,save_path):
    '''Saves to specified path a file with the date as name downloaded from the formatted url.'''
    with urllib.request.urlopen(url) as response, open(save_path+date+'.json', 'wb') as out_file:
        shutil.copyfileobj(response, out_file)

# %% [markdown]
# Using the functions should retrieve the desired data in raw-format:

# %%
dates_list = create_list_of_dates(start_date,end_date)
for date in dates_list:
    date = date.strftime("%Y%m%d")
    url = create_request_url(date,station_id,key='<api_key>')
    print(url)
    #download_one_day_readings(date,url,save_path)
# Out:
# http://api.wunderground.com/api/<api_key>/history_20160101/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160102/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160103/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160104/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160105/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160106/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160107/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160108/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160109/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160110/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160111/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160112/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160113/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160114/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160115/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160116/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160117/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160118/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160119/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160120/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160121/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160122/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160123/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160124/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160125/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160126/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160127/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160128/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160129/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160130/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160131/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160201/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160202/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160203/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160204/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160205/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160206/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160207/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160208/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160209/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160210/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160211/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160212/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160213/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160214/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160215/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160216/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160217/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160218/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160219/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160220/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160221/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160222/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160223/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160224/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160225/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160226/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160227/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160228/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160229/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160301/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160302/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160303/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160304/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160305/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160306/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160307/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160308/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160309/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160310/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160311/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160312/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160313/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160314/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160315/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160316/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160317/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160318/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160319/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160320/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160321/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160322/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160323/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160324/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160325/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160326/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160327/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160328/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160329/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160330/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160331/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160401/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160402/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160403/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160404/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160405/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160406/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160407/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160408/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160409/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160410/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160411/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160412/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160413/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160414/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160415/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160416/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160417/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160418/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160419/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160420/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160421/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160422/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160423/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160424/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160425/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160426/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160427/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160428/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160429/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160430/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160501/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160502/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160503/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160504/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160505/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160506/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160507/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160508/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160509/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160510/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160511/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160512/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160513/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160514/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160515/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160516/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160517/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160518/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160519/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160520/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160521/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160522/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160523/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160524/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160525/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160526/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160527/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160528/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160529/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160530/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160531/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160601/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160602/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160603/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160604/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160605/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160606/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160607/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160608/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160609/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160610/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160611/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160612/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160613/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160614/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160615/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160616/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160617/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160618/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160619/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160620/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160621/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160622/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160623/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160624/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160625/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160626/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160627/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160628/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160629/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160630/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160701/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160702/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160703/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160704/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160705/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160706/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160707/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160708/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160709/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160710/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160711/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160712/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160713/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160714/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160715/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160716/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160717/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160718/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160719/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160720/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160721/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160722/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160723/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160724/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160725/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160726/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160727/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160728/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160729/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160730/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160731/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160801/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160802/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160803/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160804/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160805/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160806/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160807/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160808/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160809/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160810/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160811/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160812/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160813/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160814/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160815/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160816/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160817/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160818/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160819/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160820/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160821/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160822/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160823/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160824/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160825/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160826/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160827/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160828/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160829/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160830/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160831/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160901/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160902/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160903/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160904/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160905/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160906/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160907/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160908/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160909/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160910/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160911/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160912/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160913/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160914/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160915/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160916/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160917/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160918/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160919/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160920/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160921/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160922/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160923/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160924/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160925/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160926/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160927/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160928/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160929/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20160930/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161001/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161002/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161003/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161004/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161005/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161006/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161007/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161008/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161009/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161010/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161011/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161012/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161013/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161014/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161015/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161016/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161017/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161018/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161019/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161020/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161021/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161022/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161023/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161024/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161025/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161026/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161027/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161028/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161029/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161030/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161031/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161101/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161102/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161103/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161104/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161105/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161106/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161107/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161108/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161109/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161110/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161111/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161112/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161113/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161114/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161115/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161116/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161117/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161118/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161119/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161120/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161121/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161122/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161123/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161124/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161125/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161126/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161127/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161128/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161129/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161130/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161201/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161202/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161203/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161204/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161205/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161206/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161207/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161208/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161209/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161210/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161211/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161212/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161213/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161214/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161215/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161216/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161217/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161218/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161219/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161220/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161221/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161222/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161223/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161224/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161225/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161226/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161227/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161228/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161229/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161230/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20161231/q/pws:KHIKAPOL23.json
# http://api.wunderground.com/api/<api_key>/history_20170101/q/pws:KHIKAPOL23.json
